# %% [markdown]
# C:\Users\anais\Desktop\Master\2 Semeste\MDatos\Prac 3\Datos INE

# %%
from carga import cargar_archivos

# Llamar a la función para cargar y leer archivos CSV
dataframes_cargados = cargar_archivos()
# Out:
# Por favor, ingresa la ruta del directorio donde se encuentran los archivos CSV:  C:\Users\anais\Desktop\Master\2 Semeste\MDatos\Prac 3\Datos INE
# Archivo 'Distribución porcentual de los viajeros residentes por provincias y comunidades y ciudades autónomas de procedencia.csv' cargado como 'df1':
#   Provincias Comunidad autónoma de procedencia  Total
# 0      Total                             Total    100
# 1      Total                         Andalucía  17,64
# 2      Total                            Aragón   2,73
# 3      Total           Asturias, Principado de   2,32
# 4      Total                    Balears, Illes   2,07
# Archivo 'Estancia media de los viajeros por provincias, residencia y meses.csv' cargado como 'df2':
#   Provincias Residencia    Meses Total
# 0   Albacete      Total    Total  1,93
# 1   Albacete      Total    Enero  1,62
# 2   Albacete      Total  Febrero  1,72
# 3   Albacete      Total    Marzo  1,74
# 4   Albacete      Total    Abril  1,82
# ...

# %%
from limpia import limpiar_datos

# Verificar si se cargaron los DataFrames correctamente
if dataframes_cargados:
    # Llamar a la función para limpiar y analizar los datos
    dataframes_limpios = limpiar_datos(dataframes_cargados)

    # Verificar si se devolvió el diccionario de DataFrames actualizado
    if dataframes_limpios:
        print("DataFrames actualizados después de la limpieza:")
        for df_name, df in dataframes_limpios.items():
            print(f"DataFrame: {df_name}")
            display(df.head())
    else:
        print("No se devolvió ningún DataFrame después de la limpieza.")
else:
    print("No se cargaron DataFrames.")
# Out:
# Por favor, introduce el año sobre el que deseas realizar el análisis:  2022
# No se encontró una columna 'Periodo' en el DataFrame 'df1'.
# No se encontró una columna 'Periodo' en el DataFrame 'df2'.
#
# Datos para el año 2022 del DataFrame 'df3':
#                Edad           Duración              Destino  \
# 1             Total              Total                Total
# 10            Total              Total                Total
# 19            Total              Total          Solo España
# 28            Total              Total          Solo España
# 37            Total              Total      Solo extranjero
# ...             ...                ...                  ...
# 1468  65 y más años  De 4 o más noches          Solo España
# 1477  65 y más años  De 4 o más noches      Solo extranjero
# 1486  65 y más años  De 4 o más noches      Solo extranjero
# 1495  65 y más años  De 4 o más noches  España y extranjero
# 1504  65 y más años  De 4 o más noches  España y extranjero
#
# ...

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px

# Datos de ejemplo
df = px.data.gapminder().query("country=='Canada'")

# Inicializar la aplicación
app = dash.Dash(__name__)

# Diseñar la aplicación
app.layout = html.Div([
    html.H1("Infografía Interactiva"),
    dcc.Graph(id='graph'),
    html.Div([
        html.Label("Selecciona un año:"),
        dcc.Slider(
            id='year-slider',
            min=df['year'].min(),
            max=df['year'].max(),
            value=df['year'].min(),
            marks={str(year): str(year) for year in df['year'].unique()},
            step=None
        )
    ])
])

# Callback para actualizar el gráfico
@app.callback(
    Output('graph', 'figure'),
    [Input('year-slider', 'value')]
)
def update_figure(selected_year):
    filtered_df = df[df.year == selected_year]
    fig = px.scatter(filtered_df, x="gdpPercap", y="lifeExp",
                     size="pop", color="continent", hover_name="country",
                     log_x=True, size_max=60)
    return fig

# Ejecutar la aplicación
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# C:\Users\anais\AppData\Local\Temp\ipykernel_16748\448896539.py:2: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# C:\Users\anais\AppData\Local\Temp\ipykernel_16748\448896539.py:3: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
